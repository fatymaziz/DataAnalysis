# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
import pandas as pd

# Load the Excel file
excel_file = 'Prev_results/static_dictionary_Firefox.json.xlsx'  # Replace with your Excel file path

# Read the two sheets
df_severe = pd.read_excel(excel_file, sheet_name='Severe Lexicons')  # Replace with your sheet name if different
df_nonsevere = pd.read_excel(excel_file, sheet_name='NonSevere Lexicons')  # Replace with your sheet name if different

# Drop the 'Ratio' column if it exists
if 'Ratio' in df_severe.columns:
    df_severe = df_severe.drop(columns=['Ratio'])
if 'Ratio' in df_nonsevere.columns:
    df_nonsevere = df_nonsevere.drop(columns=['Ratio'])

# Convert the DataFrames to text files
df_severe.to_csv('severe_lsvm_F.txt', sep='\t', index=False)
df_nonsevere.to_csv('nonsevere_lsvm_F.txt', sep='\t', index=False)

print("Excel sheets have been converted to 'severe_lsvm.txt' and 'nonsevere_lsvm.txt' without the 'Ratio' column")
# Out:
# Excel sheets have been converted to 'severe_lsvm.txt' and 'nonsevere_lsvm.txt' without the 'Ratio' column

# %%
# # Load positive and negative words from Bing Liu Lexicon
# with open('positive-words.txt', 'r') as f:
#     words = set(f.read().splitlines())

# with open('negative-words.txt', 'r') as f:
#     negative_words = set(f.read().splitlines())

# %%
bugs_eclipse = pd.read_csv("bugs_eclipse.csv")


bugs_eclipse['Type'] = np.where(bugs_eclipse['Severity'] == 'enhancement', "enhancement", "defect")


# Dropped rows with severity level '--'
bugs_eclipse = bugs_eclipse[bugs_eclipse["Severity"].str.contains("--")==False].reset_index()

#Dropped rows with Type "Enhancement" and "Task" because they are not a bug but a new feature
indexSevere = bugs_eclipse[(bugs_eclipse['Type'] == 'enhancement') & (bugs_eclipse['Type'] == 'enhancement') ].index
bugs_eclipse.drop(indexSevere , inplace=True)

indexSevere = bugs_eclipse[(bugs_eclipse['Type'] == 'task') & (bugs_eclipse['Type'] == 'task') ].index
bugs_eclipse.drop(indexSevere , inplace=True)


#Catagorise the severity level into a Severe and Non Severe to make it a binary problem
bugs_eclipse.loc[bugs_eclipse["Severity"] == "blocker", "Severity"] = 'Severe'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "critical", "Severity"] = 'Severe'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "major", "Severity"] = 'Severe'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "S1", "Severity"] = 'Severe'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "S2", "Severity"] = 'Severe'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "S3", "Severity"] = 'NonSevere'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "normal", "Severity"] = 'NonSevere'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "minor", "Severity"] = 'NonSevere'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "trivial", "Severity"] = 'NonSevere'
bugs_eclipse.loc[bugs_eclipse["Severity"] == "S4", "Severity"] = 'NonSevere'

df = bugs_eclipse

# %%
def check_word_intersection(txt_file, df, column_name, severity_column):
    # Read the words from the text file
    with open(txt_file, 'r') as file:
        words = file.read().splitlines()
    
    # Initialize a Counter to keep track of word intersections
    word_counter = Counter()
    
    # Dictionaries to keep track of words in severe and non-severe categories
    severe_words = Counter()
    non_severe_words = Counter()
    
    # Function to find intersecting words and update the counters
    def find_intersections(text, severity):
        text_words = set(text.split())
        intersections = text_words.intersection(words)
        for word in intersections:
            word_counter[word] += 1
            if severity == 'Severe':
                severe_words[word] += 1
            elif severity == 'NonSevere':
                non_severe_words[word] += 1
        return ', '.join(intersections) if intersections else None
    
    # Check for intersections in the DataFrame column
    df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
    # Words that appear in both categories
    both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
    # Words that appear only in severe category
    only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
    # Words that appear only in non-severe category
    only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
    # Return the DataFrame with the intersections column and the word counters
    return df, word_counter, both_categories, only_severe, only_non_severe

# Example usage:

# Assuming df is already defined and has columns named 'Summary' and 'Severity'
result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('severe_lsvm_F.txt', df, 'Summary', 'Severity')
filtered_df = result_df[result_df['intersections'].notna()]

# Print the filtered DataFrame
# print(filtered_df['intersections'])
# print(set(filtered_df['intersections']))

# Print the word counts
print(word_counts)

# Print the categorized words
# print("Words in both categories:", both_categories)
print("Words only in severe category:", only_severe)
print("Words only in non-severe category:", only_non_severe)
# Out:
# Counter({'not': 4470, 'error': 1001, 'server': 870, 'validation': 770, 'wizard': 761, 'new': 581, 'work': 494, 'missing': 477, 'fails': 461, 'type': 454, 'build': 426, 'using': 385, 'attribute': 385, 'runtime': 355, 'use': 344, 'exception': 338, 'code': 337, 'module': 329, 'support': 329, 'cannot': 281, 'create': 276, 'incorrect': 274, 'message': 269, 'add': 268, 'extension': 264, 'model': 260, 'plugin': 257, 'open': 249, 'preference': 237, 'creation': 233, 'client': 232, 'working': 223, 'properly': 221, 'problem': 216, 'context': 209, 'workspace': 208, 'invalid': 202, 'import': 200, 'xml': 198, 'created': 189, 'broken': 182, 'opening': 177, 'used': 174, 'editing': 173, 'without': 167, 'documentation': 160, 'found': 156, 'incorrectly': 153, 'package': 152, 'multiple': 151, 'handle': 144, 'action': 144, 'publish': 144, 'running': 135, 'start': 134, 'due': 133, 'component': 128, 'node': 122, 'configuration': 122, 'time': 121, 'reference': 120, 'user': 119, 'first': 114, 'cause': 113, 'launch': 113, 'duplicate': 111, 'appear': 109, 'install': 108, 'display': 108, 'dynamic': 107, 'enabled': 106, 'edit': 101, 'trying': 96, 'displayed': 91, 'entry': 90, 'many': 87, 'still': 87, 'deleting': 87, 'load': 86, 'failed': 86, 'failing': 83, 'provider': 82, 'help': 82, 'may': 81, 'deleted': 80, 'publishing': 80, 'operation': 80, 'appears': 79, 'save': 78, 'long': 76, 'showing': 75, 'selecting': 74, 'platform': 73, 'label': 73, 'closing': 71, 'case': 70, 'thread': 70, 'local': 70, 'end': 69, 'valid': 68, 'application': 68, 'two': 67, 'never': 67, 'script': 66, 'creates': 65, 'large': 65, 'getting': 65, 'imported': 65, 'loading': 64, 'loop': 63, 'unable': 63, 'installed': 63, 'usage': 63, 'combo': 62, 'data': 60, 'single': 60, 'related': 59, 'call': 59, 'longer': 58, 'memory': 58, 'closed': 56, 'containing': 55, 'updating': 55, 'must': 55, 'app': 55, 'remote': 54, 'task': 54, 'override': 54, 'unit': 54, 'box': 54, 'opened': 54, 'respect': 53, 'event': 52, 'implementation': 52, 'causing': 51, 'specify': 51, 'read': 51, 'match': 51, 'possible': 51, 'port': 51, 'session': 50, 'latest': 50, 'encoding': 50, 'restart': 50, 'resolved': 50, 'installing': 50, 'lost': 49, 'generates': 49, 'parent': 48, 'result': 48, 'exists': 48, 'occurs': 47, 'download': 47, 'cache': 47, 'hang': 46, 'automatically': 46, 'started': 43, 'current': 43, 'complete': 43, 'truncated': 42, 'validated': 42, 'typing': 41, 'switching': 41, 'copy': 41, 'includes': 40, 'caused': 40, 'back': 39, 'blank': 39, 'initial': 38, 'behavior': 37, 'binding': 37, 'exported': 37, 'checkbox': 36, 'exporting': 36, 'handled': 36, 'returned': 36, 'sample': 35, 'false': 35, 'process': 35, 'src': 35, 'core': 34, 'undefined': 34, 'optional': 33, 'break': 33, 'incomplete': 33, 'shutdown': 33, 'calling': 32, 'fixed': 32, 'keyboard': 32, 'prefix': 32, 'checked': 32, 'modified': 31, 'since': 30, 'proxy': 30, 'lock': 30, 'active': 29, 'stream': 29, 'attempting': 29, 'ui': 29, 'top': 29, 'associated': 27, 'corrupted': 27, 'see': 27, 'main': 27, 'much': 27, 'deletes': 27, 'switch': 27, 'tool': 26, 'preview': 26, 'sheet': 26, 'modify': 26, 'cursor': 25, 'fully': 25, 'standard': 25, 'moved': 24, 'control': 24, 'conflict': 24, 'last': 24, 'auto': 24, 'made': 23, 'zip': 23, 'crash': 23, 'installation': 23, 'whitespace': 23, 'infinite': 22, 'drag': 22, 'registered': 22, 'layout': 22, 'several': 22, 'detected': 22, 'given': 22, 'produce': 22, 'uri': 21, 'folding': 21, 'caching': 21, 'refreshed': 21, 'behaviour': 21, 'tooltip': 21, 'disappears': 21, 'strategy': 21, 'header': 21, 'displaying': 20, 'matching': 20, 'populated': 20, 'unknown': 20, 'persistent': 20, 'prompt': 20, 'machine': 19, 'done': 19, 'previous': 19, 'disappear': 19, 'go': 18, 'freeze': 18, 'execution': 18, 'member': 18, 'undo': 18, 'testing': 18, 'compatibility': 18, 'database': 18, 'recent': 17, 'placed': 17, 'saved': 17, 'edits': 17, 'look': 17, 'full': 17, 'toolbar': 17, 'dependancies': 16, 'lookup': 16, 'triggered': 16, 'making': 16, 'honor' ...
# Words only in severe category: {'succeed', 'toolkit', 'internally', 'accessed', 'ascii', 'architecture', 'forth', 'eventually', 'firing', 'blocker', 'unsafe', 'messed', 'layer', 'zh', 'however', 'mail', 'unpacked', 'spanish', 'erase', 'extreme', 'killing', 'ver', 'garbled', 'reliably', 'installer'}
# Words only in non-severe category: {'partition', 'pause', 'attemping', 'warn', 'massive', 'terminates', 'pretty', 'nearly', 'together', 'whitespace', 'follows', 'anywhere', 'prompting', 'deactivated', 'middle', 'concurrent', 'designed', 'draw', 'unstable', 'sign', 'upgraded', 'phantom', 'username', 'ssl', 'mac', 'minimize', 'book', 'printing', 'byte', 'enumeration', 'receive', 'synched', 'webserver', 'quite', 'want', 'tried', 'hog', 'preserve', 'excessive', 'appearance', 'connect', 'force', 'crashed', 'people', 'logo', 'fill', 'asked', 'appropriate', 'let', 'consecutive', 'bound', 'optimized', 'forward', 'retain', 'abort', 'assumed', 'free', 'future', 'floating', '""', 'rewrite', 'choosing', 'confuse', 'thousand', 'changeable', 'smaller', 'interval', 'private', 'attempt', 'inconsistency', 'fuzzy', 'purge', 'busted', 'permanently', 'backup', 'collision', 'reach', 'specification', 'alarm', 'blue', 'limitation', 'participant', 'operate', 'repeat', 'accented', 'lack', 'scheme', 'fine', 'vary', 'arrow', 'reuse', 'transfer', 'depending', 'linefeeds', 'redundancy', 'orbit', 'inaccurate', 'scrollbars', 'news', 'owner', 'enough', 'please', 'viewing', 'digest', 'attempted', 'spell', 'maybe', 'readable', 'everything', 'cross', 'ext', 'grayed', 'software', 'area', 'special', 'email', 'previously', 'shifted', 'xxx', 'inot', 'inspect', 'span', 'ca', 'dissapear', 'preselected', 'differently', 'localized', 'lot', 'leaving', 'happen', 'orientation', 'compare', 'potential', 'offline', 'press', 'erratic', 'crossing', 'iterator', 'escaping', 'corrupt', 'towards', 'int', 'corrected', 'exiting', 'installable', 'auth', 'percent', 'dialogue', 'authorization', 'attention', 'terminal', 'mix', 'calendar', 'home', 'wanted', 'adjusted', 'menuitem', 'program', 'infinity', 'mangled', 'sorting', 'dealing', 'idle', 'cyrillic', 'integer', 'invisible', 'bind', 'viewed', 'modifiying', 'inserting', 'ordered', 'backward', 'green', 'anyway', 'truncates', 'important', 'menubar', 'outgoing', 'admin', 'bloat', 'forgets', 'german', 'manage', 'ugly', 'bringing', 'oracle', 'writes', 'light'}

# %%
def check_word_intersection(txt_file, df, column_name, severity_column):
    # Read the words from the text file
    with open(txt_file, 'r') as file:
        words = file.read().splitlines()
    
    # Initialize a Counter to keep track of word intersections
    word_counter = Counter()
    
    # Dictionaries to keep track of words in severe and non-severe categories
    severe_words = Counter()
    non_severe_words = Counter()
    
    # Function to find intersecting words and update the counters
    def find_intersections(text, severity):
        text_words = set(text.split())
        intersections = text_words.intersection(words)
        for word in intersections:
            word_counter[word] += 1
            if severity == 'Severe':
                severe_words[word] += 1
            elif severity == 'NonSevere':
                non_severe_words[word] += 1
        return ', '.join(intersections) if intersections else None
    
    # Check for intersections in the DataFrame column
    df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
    # Words that appear in both categories
    both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
    # Words that appear only in severe category
    only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
    # Words that appear only in non-severe category
    only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
    # Return the DataFrame with the intersections column and the word counters
    return df, word_counter, both_categories, only_severe, only_non_severe

# Example usage:

# Assuming df is already defined and has columns named 'Summary' and 'Severity'
result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('nonsevere_lsvm_F.txt', df, 'Summary', 'Severity')
filtered_df = result_df[result_df['intersections'].notna()]

# Print the filtered DataFrame
# print(filtered_df)
# print(set(filtered_df['intersections']))

# Print the word counts
print(word_counts)

# Print the categorized words
# print("Words in both categories:", both_categories)
print("Words only in severe category:", only_severe)
print("Words only in non-severe category:", only_non_severe)
# Out:
# Counter({'project': 1627, 'file': 1178, 'editor': 795, 'page': 725, 'view': 572, 'web': 564, 'name': 456, 'source': 438, 'content': 424, 'version': 410, 'class': 388, 'default': 387, 'update': 361, 'service': 344, 'tag': 294, 'need': 287, 'dialog': 279, 'test': 274, 'schema': 259, 'set': 251, 'creating': 248, 'wrong': 248, 'change': 245, 'folder': 244, 'show': 243, 'element': 226, 'java': 217, 'correctly': 214, 'jar': 212, 'text': 208, 'menu': 207, 'method': 203, 'selection': 199, 'remove': 198, 'added': 196, 'plugins': 194, 'empty': 192, 'adding': 190, 'mapping': 190, 'property': 187, 'always': 182, 'path': 181, 'button': 180, 'get': 169, 'value': 167, 'warning': 164, 'performance': 159, 'updated': 153, 'thrown': 151, 'dependency': 151, 'library': 147, 'generated': 146, 'resource': 146, 'run': 144, 'feature': 142, 'point': 141, 'function': 140, 'list': 139, 'target': 138, 'field': 137, 'removed': 133, 'available': 133, 'entity': 133, 'contains': 132, 'selected': 132, 'directory': 130, 'line': 129, 'check': 129, 'include': 123, 'instead': 123, 'string': 122, 'root': 122, 'one': 122, 'existing': 119, 'framework': 119, 'log': 119, 'shown': 114, 'internal': 113, 'variable': 111, 'document': 110, 'changing': 108, 'setting': 107, 'location': 106, 'link': 105, 'failure': 105, 'access': 105, 'option': 104, 'startup': 102, 'needed': 101, 'even': 101, 'required': 100, 'tab': 97, 'generation': 96, 'syntax': 95, 'via': 95, 'explorer': 94, 'defined': 94, 'allow': 93, 'bug': 93, 'inside': 93, 'table': 91, 'fix': 90, 'custom': 90, 'delete': 90, 'key': 90, 'called': 87, 'javascript': 87, 'html': 86, 'disabled': 86, 'fail': 86, 'column': 86, 'object': 86, 'outline': 85, 'changed': 84, 'return': 83, 'debug': 83, 'export': 83, 'slow': 83, 'specified': 83, 'twice': 82, 'site': 81, 'different': 81, 'static': 80, 'container': 79, 'level': 79, 'external': 78, 'mode': 77, 'way': 77, 'within': 77, 'information': 76, 'icon': 76, 'unused': 76, 'find': 75, 'correct': 74, 'included': 74, 'compile': 73, 'scenario': 73, 'completion': 73, 'deadlock': 71, 'importing': 71, 'doc': 70, 'supported': 70, 'reported': 70, 'formatting': 70, 'comment': 68, 'rename': 68, 'occurred': 67, 'child': 67, 'generating': 67, 'issue': 66, 'tree': 65, 'starting': 65, 'removing': 64, 'structure': 63, 'format': 63, 'api': 62, 'id': 62, 'right': 61, 'select': 61, 'provide': 60, 'state': 60, 'specific': 60, 'space': 60, 'tomcat': 60, 'validate': 59, 'based': 59, 'ignores': 59, 'status': 59, 'builder': 58, 'exist': 58, 'ignored': 58, 'move': 58, 'marked': 58, 'catalog': 57, 'simple': 57, 'another': 57, 'improve': 57, 'make': 56, 'resolve': 56, 'building': 55, 'info': 55, 'output': 55, 'config': 54, 'report': 54, 'description': 53, 'number': 53, 'window': 52, 'already': 52, 'better': 52, 'panel': 52, 'definition': 52, 'metadata': 51, 'requires': 51, 'input': 50, 'leak': 50, 'drop': 50, 'binary': 50, 'able': 49, 'handling': 49, 'refresh': 49, 'interface': 48, 'copyright': 48, 'certain': 48, 'sync': 48, 'deprecated': 48, 'unnecessary': 48, 'could': 48, 'license': 47, 'clean': 47, 'order': 47, 'inconsistent': 47, 'common': 47, 'system': 47, 'clicking': 47, 'extra': 46, 'listener': 46, 'search': 46, 'section': 46, 'cleanup': 46, 'published': 46, 'release': 45, 'lib': 45, 'sometimes': 45, 'archive': 45, 'item': 45, 'rule': 45, 'recognized': 44, 'patch': 44, 'index': 44, 'click': 44, 'command': 44, 'filter': 44, 'outside': 43, 'manifest': 43, 'non': 43, 'old': 42, 'navigator': 42, 'close': 42, 'character': 42, 'virtual': 42, 'style': 42, 'listed': 42, 'color': 42, 'like': 42, 'recognize': 41, 'statement': 41, 'renaming': 41, 'monitor': 41, 'allows': 41, 'console': 41, 'visible': 41, 'disable': 41, 'contain': 41, 'relative': 40, 'parsing': 40, 'logged': 40, 'browser': 40, 'generator': 39, 'proper': 39, 'background': 39, 'implement': 38, 'additional': 38, 'loaded': 38, 'map': 38, 'declaration': 38, 'date': 38, 'bad': 38, 'copied': 37, 'translation': 37, 'part': 37, 'present': 37, 'repository ...
# Words only in severe category: {'popups', 'erratically', 'encrypted', 'reached', 'neither', 'sharing', 'crashing', 'favorite', 'safety', 'operational', 'compose', 'deactivating', 'filling', 'refuse', 'storing', 'vulnerability', 'organized', 'spike', 'exporter', 'decorated', 'scale', 'disconnected', 'responsive', 'co', 'reboot', 'cs', 'weekly', 'hibernate', 'acknowledge', 'occuring', 'wider', 'rapid', 'forbids', 'animation', 'reordering', 'push', 'timing', 'authentication', 'affecting', 'repetitive', 'unloaded', 'strip', 'everytime', 'major', 'protection', 'bootstrap', 'duplication', 'recently', 'recorded', 'lion', 'simultaneous', 'textfield', 'miss', 'looping', 'unix', 'extracting', 'resync', 'delegated', 'occurence', 'shift'}
# Words only in non-severe category: {'management', 'existant', 'person', 'significantly', 'isnt', 'bookmark', 'accepted', 'configure', 'assert', 'equivalent', 'ad', 'supposed', 'originating', 'functioning', 'slowly', 'dictionary', 'hiding', 'fishy', 'selector', 'colour', 'filesystem', 'frame', 'busy', 'automatic', 'year', 'ellipsis', 'unfinished', 'little', 'spacing', 'delimited', 'missed', 'separated', 'messy', 'popular', 'horizontally', 'instruction', 'alt', 'align', 'navigating', 'resizing', 'automate', 'incoming', 'pl', 'fast', 'decide', 'simplify', 'periodically', 'bugzilla', 'indicator', 'initialise', 'accepts', 'locally', 'improving', 'thing', 'bold', 'preserved', 'launcher', 'upcoming', 'plan', 'detailed', 'submenu', 'exclusive', 'foreign', 'reader', 'consolidate', 'larger', 'print', 'succeeds', 'conversion', 'third', 'restriction', 'told', 'searched', 'flicker', 'unreachable', 'gray', 'confirm', 'accommodate', 'offer', 'synchronizing', 'shape', 'blanked', 'compatability', 'calculate', 'collapsed', 'subfolders', 'hovering', 'minor', 'nightmare', 'permission', 'coded', 'dropped', 'serialization', 'branding', 'hung', 'decode', 'perhaps', 'confuses', 'workflow', 'care', 'tip', 'writable', 'spelt', 'availability', 'official', 'difficult', 'reasonable', 'smooth', 'pound', 'cert', 'schedule', 'ampersand', 'tweak', 'cell', 'direct', 'illegible', 'integrated', 'recreating', 'greater', 'world', 'likely', 'planned', 'yellow', 'glitch', 'conform', 'nightly', 'obvious', 'detection', 'device', 'partly', 'extesion', 'percentage', 'redirect', 'revisit', 'json', 'dragged', 'transparent', 'licence', 'month', 'visiting', 'stage', 'viewport', 'highlight', 'firefox', 'sized', 'accidentally', 'continually', 'customize', 'repetition', 'wildcard', 'contrast', 'wording', 'real', 'folded', 'native', 'acceptance', 'black', 'rest', 'restoring', 'updater', 'spuriously', 'disconnecting', 'ignoring', 'inverted', 'restrict', 'attachment', 'belong', 'grab', 'remembered', 'welcome', 'keybindings', 'low', 'subsequent', 'incompatibility', 'cancellation', 'abnormal', 'lagging', 'occurrence', 'scoped', 'numeric', 'choose', 'dismiss', 'funny', 'falling', 'skin', 'dash', 'clipped', 'overlapping', 'colon', 'faster', 'referred', 'unify', 'leakage', 'potentially', 'annoying', 'barely', 'agressive', 'converted', 'leave', 'online', 'inefficient', 'xulrunner', 'scrollbar', 'continuously', 'detects', 'history', 'wheel', 'footer', 'identity', 'keywords', 'misplaced', 'chinese', 'flashing', 'positive', 'initialised', 'trailing', 'distributed', 'shadow', 'border', 'compact', 'ping', 'ahead', 'sometime', 'follow', 'investigate', 'prior', 'underline', 'clicked', 'ordering', 'fall', 'possibility', 'maximum', 'completed', 'audio', 'receiving', 'misbehaviour', 'occasionally', 'disagree', 'toggled', 'continues', 'friendly', 'edge', 'paint', 'trash', 'useless', 'downloaded', 'track', 'toggle', 'asking', 'unclear', 'row', 'hosted', 'printed', 'watch', 'expandable', 'affected', 'oddly', 'ensure', 'entered', 'bracket', 'production', 'showed', 'sends', 'asks', 'uncheck', 'finished', 'minimum', 'outdated', 'hardcode', 'studio', 'deselected', 'navigate', 'validity', 'forget', 'differs', 'repaint', 'plug', 'slot', 'typed', 'scheduled', 'weird', 'slave', 'accessibility', 'listening', 'maximize', 'unhelpful', 'reorganize', 'forbidden', 'backspace', 'mod', 'printout', 'serialize', 'pull', 'slightly', 'figure', 'cryptic', 'mean', 'duplicating', 'edition', 'fetch', 'ask', 'unpack', 'writing', 'original', 'insufficient', 'overview', 'wrapping', 'procedure', 'limited', 'beta', 'grey', 'readonly', 'contextual', 'append', 'unread', 'trapped', 'height', 'suggested', 'colored', 'total', 'margin', 'self', 'ip', 'cancelling', 'screenshot', 'signing', 'revise', 'symbol', 'video', 'calculation', 'connectivity', 'position', 'fly', 'const', 'dom', 'though', 'localization', 'confusion', 'ton', 'us', 'reverts', 'arbitrarily', 'propagate', 'alias', 'applies', 'sequential', 'collapse', 'shrink', 'half' ...

# %%
# import pandas as pd
# from collections import Counter

# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Debug prints to check the counts
#     print("Severe words count:", severe_words)
#     print("Non-severe words count:", non_severe_words)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('positive-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('positive-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('negative-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# import pandas as pd
# from collections import Counter

# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Function to find intersecting words and update the counter
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column and the word counter
#     return df, word_counter

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df, word_counts = check_word_intersection('positive-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# %%
# bugs_df['Processed_Summary'] = bugs_df['Summary'].apply(lambda x: helper.nlpsteps(x))

# %%
# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Function to find intersecting words
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column
#     return df

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df = check_word_intersection('positive-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(set(filtered_df['intersections']))
# # print(result_df)

# %%
# import pandas as pd

# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Function to find intersecting words
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column
#     return df

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df = check_word_intersection('negative-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(set(filtered_df['intersections']))
# # print(result_df)
