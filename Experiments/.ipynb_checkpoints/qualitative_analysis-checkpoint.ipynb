# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
import pandas as pd

# Load the Excel file
excel_file = 'Prev_results/static_Final_Lexicon_4_LSVM.xlsx'  # Replace with your Excel file path

# Read the two sheets
df_severe = pd.read_excel(excel_file, sheet_name='Severe Lexicons')  # Replace with your sheet name if different
df_nonsevere = pd.read_excel(excel_file, sheet_name='NonSevere Lexicons')  # Replace with your sheet name if different

# Drop the 'Ratio' column if it exists
if 'Ratio' in df_severe.columns:
    df_severe = df_severe.drop(columns=['Ratio'])
if 'Ratio' in df_nonsevere.columns:
    df_nonsevere = df_nonsevere.drop(columns=['Ratio'])

# Convert the DataFrames to text files
df_severe.to_csv('severe_threshold_LSVM.txt', sep='\t', index=False)
df_nonsevere.to_csv('nonsevere_threshold_LSVM.txt', sep='\t', index=False)

print("Excel sheets have been converted to 'severe_lsvm.txt' and 'nonsevere_lsvm.txt' without the 'Ratio' column")
# Out:
# Excel sheets have been converted to 'severe_lsvm.txt' and 'nonsevere_lsvm.txt' without the 'Ratio' column

# %%
# # Load positive and negative words from Bing Liu Lexicon
# with open('positive-words.txt', 'r') as f:
#     words = set(f.read().splitlines())

# with open('negative-words.txt', 'r') as f:
#     negative_words = set(f.read().splitlines())

# %%
# bugs_eclipse = pd.read_csv("bugs_eclipse.csv")


# bugs_eclipse['Type'] = np.where(bugs_eclipse['Severity'] == 'enhancement', "enhancement", "defect")


# # Dropped rows with severity level '--'
# bugs_eclipse = bugs_eclipse[bugs_eclipse["Severity"].str.contains("--")==False].reset_index()

# #Dropped rows with Type "Enhancement" and "Task" because they are not a bug but a new feature
# indexSevere = bugs_eclipse[(bugs_eclipse['Type'] == 'enhancement') & (bugs_eclipse['Type'] == 'enhancement') ].index
# bugs_eclipse.drop(indexSevere , inplace=True)

# indexSevere = bugs_eclipse[(bugs_eclipse['Type'] == 'task') & (bugs_eclipse['Type'] == 'task') ].index
# bugs_eclipse.drop(indexSevere , inplace=True)


# #Catagorise the severity level into a Severe and Non Severe to make it a binary problem
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "blocker", "Severity"] = 'Severe'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "critical", "Severity"] = 'Severe'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "major", "Severity"] = 'Severe'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "S1", "Severity"] = 'Severe'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "S2", "Severity"] = 'Severe'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "S3", "Severity"] = 'NonSevere'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "normal", "Severity"] = 'NonSevere'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "minor", "Severity"] = 'NonSevere'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "trivial", "Severity"] = 'NonSevere'
# bugs_eclipse.loc[bugs_eclipse["Severity"] == "S4", "Severity"] = 'NonSevere'

# df = bugs_eclipse

# %%
bugs_df = pd.read_csv("bugs_firefox.csv")
# Dropped rows with severity level '--'
bugs_df = bugs_df[bugs_df["Severity"].str.contains("--")==False].reset_index()

#Dropped rows with Type "Enhancement" and "Task" because they are not a bug but a new feature
indexSevere = bugs_df[ (bugs_df['Type'] == 'enhancement') & (bugs_df['Type'] == 'enhancement') ].index
bugs_df.drop(indexSevere , inplace=True)

indexSevere = bugs_df[ (bugs_df['Type'] == 'task') & (bugs_df['Type'] == 'task') ].index
bugs_df.drop(indexSevere , inplace=True)


#Catagorise the severity level into a Severe and Non Severe to make it a binary problem
bugs_df.loc[bugs_df["Severity"] == "blocker", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "critical", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "major", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S1", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S2", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S3", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "normal", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "minor", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "trivial", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "S4", "Severity"] = 'NonSevere'

df = bugs_df

# %%
def check_word_intersection(txt_file, df, column_name, severity_column):
    # Read the words from the text file
    with open(txt_file, 'r') as file:
        words = file.read().splitlines()
    
    # Initialize a Counter to keep track of word intersections
    word_counter = Counter()
    
    # Dictionaries to keep track of words in severe and non-severe categories
    severe_words = Counter()
    non_severe_words = Counter()
    
    # Function to find intersecting words and update the counters
    def find_intersections(text, severity):
        text_words = set(text.split())
        intersections = text_words.intersection(words)
        for word in intersections:
            word_counter[word] += 1
            if severity == 'Severe':
                severe_words[word] += 1
            elif severity == 'NonSevere':
                non_severe_words[word] += 1
        return ', '.join(intersections) if intersections else None
    
    # Check for intersections in the DataFrame column
    df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
    # Words that appear in both categories
    both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
    # Words that appear only in severe category
    only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
    # Words that appear only in non-severe category
    only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
    # Return the DataFrame with the intersections column and the word counters
    return df, word_counter, both_categories, only_severe, only_non_severe

# Example usage:

# Assuming df is already defined and has columns named 'Summary' and 'Severity'
result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('nonsevere_threshold_LSVM.txt', df, 'Summary', 'Severity')
filtered_df = result_df[result_df['intersections'].notna()]

# Print the filtered DataFrame
# print(filtered_df['intersections'])
# print(set(filtered_df['intersections']))

# Print the word counts
print(word_counts)

# Print the categorized words
# print("Words in both categories:", both_categories)
print("Words only in severe category:", only_severe)
print("Words only in non-severe category:", only_non_severe)
# Out:
# Counter({'not': 1010, 'tab': 483, 'page': 353, 'bar': 322, 'window': 314, 'menu': 300, 'new': 281, 'button': 250, 'open': 209, 'search': 181, 'displayed': 171, 'bug': 163, 'using': 161, 'browser': 157, 'text': 150, 'single': 148, 'tracking': 146, 'file': 141, 'work': 137, 'icon': 135, 'mode': 134, 'panel': 131, 'toolbar': 128, 'default': 127, 'firefox': 125, 'dialog': 123, 'download': 106, 'opened': 102, 'link': 102, 'screen': 98, 'address': 98, 'instead': 97, 'user': 96, 'show': 95, 'focus': 95, 'bookmark': 92, 'set': 92, 'opening': 91, 'option': 89, 'content': 89, 'wrong': 88, 'one': 86, 'list': 86, 'context': 86, 'click': 84, 'keyboard': 82, 'update': 80, 'history': 80, 'use': 79, 'do': 78, 'correctly': 74, 'mouse': 73, 'clicking': 72, 'back': 71, 'timed': 71, 'test': 70, 'working': 70, 'display': 70, 'theme': 69, 'session': 68, 'time': 66, 'even': 65, 'right': 65, 'multiple': 65, 'different': 64, 'close': 64, 'selected': 64, 'application': 63, 'load': 63, 'size': 63, 'site': 62, 'cannot': 62, 'first': 62, 'scroll': 61, 'folder': 59, 'loading': 59, 'top': 59, 'without': 59, 'via': 58, 'missing': 57, 'popup': 57, 'restore': 57, 'appears': 57, 'get': 56, 'closed': 56, 'sometimes': 56, 'field': 56, 'url': 55, 'background': 55, 'visible': 55, 'longer': 54, 'sync': 54, 'private': 54, 'another': 54, 'title': 52, 'downloads': 52, 'shown': 51, 'disabled': 51, 'down': 51, 'saved': 50, 'change': 50, 'properly': 49, 'still': 49, 'data': 49, 'save': 49, 'appear': 48, 'key': 48, 'drop': 48, 'last': 47, 'image': 46, 'always': 46, 'closing': 46, 'incorrect': 45, 'color': 45, 'navigation': 45, 'enabled': 45, 'line': 45, 'engine': 45, 'current': 44, 'message': 44, 'previous': 44, 'state': 43, 'system': 43, 'switching': 43, 'box': 42, 'overflow': 42, 'sidebar': 41, 'input': 41, 'location': 41, 'shortcut': 40, 'notification': 40, 'scrolling': 39, 'full': 39, 'blank': 39, 'wrongly': 39, 'setting': 39, 'left': 39, 'like': 38, 'selection': 38, 'position': 38, 'indicator': 37, 'area': 37, 'extension': 37, 'empty': 37, 'loaded': 37, 'used': 37, 'web': 36, 'type': 36, 'many': 36, 'item': 36, 'space': 36, 'select': 36, 'zoom': 36, 'expected': 36, 'focused': 36, 'font': 35, 'moving': 35, 'broken': 35, 'name': 35, 'dragging': 34, 'disappears': 34, 'created': 34, 'favicon': 34, 'active': 34, 'pinned': 34, 'password': 34, 'due': 34, 'long': 34, 'support': 34, 'inside': 33, 'restored': 33, 'incorrectly': 33, 'prompt': 33, 'switch': 33, 'result': 33, 'form': 32, 'browsing': 32, 'second': 32, 'element': 32, 'view': 32, 'dropdown': 32, 'drag': 32, 'hidden': 32, 'version': 31, 'already': 31, 'match': 31, 'removed': 31, 'fullscreen': 31, 'permission': 31, 'clicked': 31, 'dark': 30, 'disappear': 30, 'add': 30, 'animation': 30, 'local': 30, 'desktop': 30, 'bottom': 30, 'code': 30, 'moved': 30, 'width': 30, 'access': 29, 'manager': 29, 'main': 29, 'certain': 29, 'hover': 29, 'behavior': 29, 'allow': 29, 'warning': 29, 'custom': 29, 'website': 29, 'arrow': 29, 'immediately': 28, 'two': 28, 'rendering': 28, 'pdf': 28, 'certificate': 28, 'app': 28, 'info': 28, 'modal': 28, 'changed': 27, 'preview': 27, 'showing': 27, 'account': 27, 'screenshot': 27, 'automatically': 27, 'small': 27, 'make': 27, 'cause': 27, 'stop': 27, 'unexpected': 27, 'border': 26, 'value': 26, 'cursor': 26, 'section': 26, 'downloaded': 26, 'updated': 26, 'blocked': 26, 'information': 26, 'process': 25, 'slow': 25, 'selecting': 25, 'move': 24, 'running': 24, 'restart': 24, 'installed': 24, 'changing': 24, 'video': 24, 'order': 24, 'available': 23, 'split': 23, 'command': 23, 'large': 23, 'me': 23, 'accessible': 23, 'find': 23, 'pressing': 23, 'remember': 23, 'look': 23, 'go': 23, 'print': 22, 'library': 22, 'taskbar': 22, 'label': 22, 'height': 22, 'failed': 22, 'preference': 22, 'refresh': 22, 'check': 22, 'specific': 22, 'suggestion': 22, 'container': 22, 'string': 22, 'home': 21, 'tag': 21, 'added': 21, 'may': 21, 'handling': 21, 'way': 21, 'downloading': 21, 'action': 21, 'exception': 21, 'hi ...
# Words only in severe category: {'structure', 'consumed', 'important', 'write', 'inspect', 'improper'}
# Words only in non-severe category: {'promoted', 'particular', 'silently', 'bumpy', 'numbered', 'welcome', 'accessed', 'improvement', 'slow', 'exactly', 'firmware', 'diverted', 'packaged', 'antialiasing', 'log', 'fxa', 'variety', 'affecting', 'rectangle', 'thumb', 'stick', 'accesskeys', 'unsafe', 'highlighting', 'bucket', 'instantly', 'later', 'updating', 'yet', 'encountered', 'entry', 'merged', 'maximizing', 'arrange', 'violation', 'mimetypes', 'autoplay', 'apostrophe', 'colorway', 'promise', 'accross', 'bugged', 'endpoint', 'msg', 'suggestion', 'modern', 'continually', 'android', 'success', 'deleted', 'small', 'autofill', 'doorhangers', 'wrapping', 'really', 'presenting', 'reactivated', 'getting', 'tabbar', 'shipped', 'visualizer', 'functionality', 'ajax', 'compact', 'lower', 'slide', 'latin', 'disable', 'notch', 'visiting', 'reflow', 'picker', 'badge', 'giant', 'gracefully', 'per', 'replace', 'repository', 'hanger', 'html', 'visually', 'online', 'reattempt', 'invoked', 'flavor', 'stutter', 'responding', 'ignored', 'footer', 'wikipedia', 'table', 'onscreen', 'come', 'shell', 'stay', 'form', 'property', 'optional', 'reducing', 'improve', 'overlay', 'average', 'spelling', 'reported', '""', 'multiset', 'accented', 'tell', 'verify', 'cartridge', 'customize', 'move', 'map', 'richlistitems', 'topic', 'bypassed', 'approx', 'cookie', 'unrecognized', 'pull', 'kerning', 'anywhere', 'persisted', 'safebrowsing', 'padlock', 'tying', 'tabstrip', 'hardcoded', 'numeral', 'webmail', 'manually', 'completion', 'scan', 'overhead', 'french', 'completely', 'headless', 'fit', 'credential', 'harmful', 'increase', 'forgotten', 'cycle', 'resource', 'inconsistently', 'modified', 'visit', 'webrtc', 'summary', 'solicitation', 'progress', 'slowly', 'dictation', 'overlapping', 'web', 'formatting', 'prefwindow', 'refreshing', 'access', 'chosen', 'tabbable', 'sub', 'retry', 'automatically', 'noisily', 'mouse', 'synced', 'sign', 'also', 'invite', 'ff', 'fallback', 'twitch', 'occurs', 'jump', 'etc', 'term', 'verisign', 'config', 'integration', 'corresponding', 'remove', 'based', 'prevented', 'kept', 'redraw', 'something', 'unhandled', 'noticeably', 'spillover', 'aol', 'topmost', 'inverted', 'teach', 'tune', 'globals', 'old', 'reordering', 'seemingly', 'cryptographic', 'disconnecting', 'styled', 'phishing', 'staged', 'intranet', 'product', 'treat', 'tabbrowser', 'shrinked', 'future', 'dissolve', 'ongoing', 'accommodate', 'broken', 'strip', 'mozplugger', 'stylesheet', 'gui', 'location', 'referrer', 'viewport', 'playing', 'interrupting', 'noticing', 'proper', 'replaced', 'understood', 'symlinks', 'terminated', 'animate', 'false', 'taxi', 'signal', 'inheriting', 'two', 'pending', 'shading', 'disabling', 'auditing', 'structured', 'xml', 'followed', 'introduced', 'shape', 'dangerous', 'enrolled', 'black', 'accept', 'network', 'debugging', 'friendly', 'reencoded', 'avoid', 'schema', 'finding', 'saying', 'hyperlink', 'push', 'misinterprets', 'case', 'generates', 'syslog', 'analysis', 'appears', 'disables', 'specific', 'unmute', 'somehow', 'terminal', 'granular', 'lacking', 'misparented', 'restriction', 'mod', 'reorderable', 'far', 'outline', 'unused', 'shifted', 'upload', 'replacing', 'dimmed', 'sound', 'help', 'feed', 'mean', 'either', 'escape', 'editable', 'retracts', 'track', 'createprocess', 'completes', 'tree', 'whose', 'infobar', 'font', 'autoscrolling', 'imgur', 'payment', 'anonymity', 'closed', 'english', 'populated', 'telemetry', 'keyboard', 'often', 'missing', 'assert', 'redirected', 'appear', 'validation', 'choosing', 'top', 'shaking', 'go', 'remain', 'considerably', 'propperly', 'timeouts', 'real', 'jumplist', 'read', 'stack', 'attention', 'addressbar', 'demo', 'serial', 'make', 'blink', 'ticked', 'scenario', 'broke', 'opaque', 'resolve', 'resends', 'td', 'grab', 'painted', 'onclick', 'ago', 'overlapped', 'experimental', 'menuitem', 'method', 'music', 'tear', 'importer', 'privilege', 'truncated', 'spinner', 'searchbar', 'aware', 'expired', 'share', 'stream ...

# %%
def check_word_intersection(txt_file, df, column_name, severity_column):
    # Read the words from the text file
    with open(txt_file, 'r') as file:
        words = file.read().splitlines()
    
    # Initialize a Counter to keep track of word intersections
    word_counter = Counter()
    
    # Dictionaries to keep track of words in severe and non-severe categories
    severe_words = Counter()
    non_severe_words = Counter()
    
    # Function to find intersecting words and update the counters
    def find_intersections(text, severity):
        text_words = set(text.split())
        intersections = text_words.intersection(words)
        for word in intersections:
            word_counter[word] += 1
            if severity == 'Severe':
                severe_words[word] += 1
            elif severity == 'NonSevere':
                non_severe_words[word] += 1
        return ', '.join(intersections) if intersections else None
    
    # Check for intersections in the DataFrame column
    df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
    # Words that appear in both categories
    both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
    # Words that appear only in severe category
    only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
    # Words that appear only in non-severe category
    only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
    # Return the DataFrame with the intersections column and the word counters
    return df, word_counter, both_categories, only_severe, only_non_severe

# Example usage:

# Assuming df is already defined and has columns named 'Summary' and 'Severity'
result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('severe_threshold_LSVM.txt', df, 'Summary', 'Severity')
filtered_df = result_df[result_df['intersections'].notna()]

# Print the filtered DataFrame
# print(filtered_df)
# print(set(filtered_df['intersections']))

# Print the word counts
print(word_counts)

# Print the categorized words
# print("Words in both categories:", both_categories)
print("Words only in severe category:", only_severe)
print("Words only in non-severe category:", only_non_severe)
# Out:
#   File "/var/folders/5d/403ycky539l56zh62k4t0x9m0000gn/T/ipykernel_44170/1337394067.py", line 43
#     result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('severe_threshold_FF
#                                                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
# import pandas as pd
# from collections import Counter

# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Debug prints to check the counts
#     print("Severe words count:", severe_words)
#     print("Non-severe words count:", non_severe_words)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('positive-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('positive-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# def check_word_intersection(txt_file, df, column_name, severity_column):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Dictionaries to keep track of words in severe and non-severe categories
#     severe_words = Counter()
#     non_severe_words = Counter()
    
#     # Function to find intersecting words and update the counters
#     def find_intersections(text, severity):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#             if severity == 'Severe':
#                 severe_words[word] += 1
#             elif severity == 'Non-Severe':
#                 non_severe_words[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df.apply(lambda row: find_intersections(row[column_name], row[severity_column]), axis=1)
    
#     # Words that appear in both categories
#     both_categories = {word for word in words if severe_words[word] > 0 and non_severe_words[word] > 0}
    
#     # Words that appear only in severe category
#     only_severe = {word for word in words if severe_words[word] > 0 and non_severe_words[word] == 0}
    
#     # Words that appear only in non-severe category
#     only_non_severe = {word for word in words if non_severe_words[word] > 0 and severe_words[word] == 0}
    
#     # Return the DataFrame with the intersections column and the word counters
#     return df, word_counter, both_categories, only_severe, only_non_severe

# # Example usage:

# # Assuming df is already defined and has columns named 'Summary' and 'Severity'
# result_df, word_counts, both_categories, only_severe, only_non_severe = check_word_intersection('negative-words.txt', df, 'Summary', 'Severity')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# # Print the categorized words
# print("Words in both categories:", both_categories)
# print("Words only in severe category:", only_severe)
# print("Words only in non-severe category:", only_non_severe)

# %%
# import pandas as pd
# from collections import Counter

# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Initialize a Counter to keep track of word intersections
#     word_counter = Counter()
    
#     # Function to find intersecting words and update the counter
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         for word in intersections:
#             word_counter[word] += 1
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column and the word counter
#     return df, word_counter

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df, word_counts = check_word_intersection('positive-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(filtered_df)

# # Print the word counts
# print(word_counts)

# %%
# bugs_df['Processed_Summary'] = bugs_df['Summary'].apply(lambda x: helper.nlpsteps(x))

# %%
# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Function to find intersecting words
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column
#     return df

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df = check_word_intersection('positive-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(set(filtered_df['intersections']))
# # print(result_df)

# %%
# import pandas as pd

# def check_word_intersection(txt_file, df, column_name):
#     # Read the words from the text file
#     with open(txt_file, 'r') as file:
#         words = file.read().splitlines()
    
#     # Function to find intersecting words
#     def find_intersections(text):
#         text_words = set(text.split())
#         intersections = text_words.intersection(words)
#         return ', '.join(intersections) if intersections else None
    
#     # Check for intersections in the DataFrame column
#     df['intersections'] = df[column_name].apply(find_intersections)
    
#     # Return the DataFrame with the intersections column
#     return df

# # Example usage:

# # Assuming df is already defined and has a column named 'Summary'
# result_df = check_word_intersection('negative-words.txt', df, 'Summary')
# filtered_df = result_df[result_df['intersections'].notna()]

# # Print the filtered DataFrame
# print(set(filtered_df['intersections']))
# # print(result_df)
