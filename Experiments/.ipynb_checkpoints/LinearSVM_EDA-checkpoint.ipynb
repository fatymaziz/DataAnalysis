# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Severe', 'Non-severe']
eclipse_bugs = [30, 70]  # Example data for Eclipse
firefox_bugs = [45, 55]  # Example data for Firefox

x = np.arange(len(categories))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, eclipse_bugs, width, label='Eclipse')
bars2 = ax.bar(x + width/2, firefox_bugs, width, label='Firefox')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Bug Type')
ax.set_ylabel('Number of Bugs')
ax.set_title('Data Distribution in Eclipse and Firefox')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import helper

# %%
bugs_df= pd.read_csv("bugs_Calendar.csv")



# Dropped rows with severity level '--'
bugs_df = bugs_df[bugs_df["Severity"].str.contains("--")==False].reset_index()

#Dropped rows with Type "Enhancement" and "Task" because they are not a bug but a new feature
indexSevere = bugs_df[ (bugs_df['Type'] == 'enhancement') & (bugs_df['Type'] == 'enhancement') ].index
bugs_df.drop(indexSevere , inplace=True)

indexSevere = bugs_df[(bugs_df['Type'] == 'task') & (bugs_df['Type'] == 'task') ].index
bugs_df.drop(indexSevere , inplace=True)


#Catagorise the severity level into a Severe and Non Severe to make it a binary problem
bugs_df.loc[bugs_df["Severity"] == "blocker", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "critical", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "major", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S1", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S2", "Severity"] = 'Severe'
bugs_df.loc[bugs_df["Severity"] == "S3", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "normal", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "minor", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "trivial", "Severity"] = 'NonSevere'
bugs_df.loc[bugs_df["Severity"] == "S4", "Severity"] = 'NonSevere'

bugs_df = bugs_df.head(200)
print(bugs_df)
# Out:
#      index   Bug ID   Product                            Component  \
# 1        1  1727061  Calendar                     Provider: CalDAV
# 3        3   458828  Calendar                     Provider: CalDAV
# 4        4   462326  Calendar                              General
# 5        5   299327  Calendar                       Lightning Only
# 6        6   301484  Calendar                  Internal Components
# ..     ...      ...       ...                                  ...
# 241    268   372424  Calendar  E-mail based Scheduling (iTIP/iMIP)
# 242    269  1346797  Calendar                              General
# 245    273   536555  Calendar                     Provider: CalDAV
# 246    274   735158  Calendar                    Calendar Frontend
# 247    275   742257  Calendar                              General
#
#                       Assignee    Status  Resolution  \
# 1       ben.bucksch@beonex.com  RESOLVED       FIXED
# 3          dbo.moz@boelzle.org  RESOLVED       FIXED
# 4          dbo.moz@boelzle.org  RESOLVED       FIXED
# 5        dmosedale@mozilla.com  RESOLVED       FIXED
# 6        dmosedale@mozilla.com  RESOLVED   DUPLICATE
# ..                         ...       ...         ...
# 241  philipp@bugzilla.kewis.ch  RESOLVED       FIXED
# 242  philipp@bugzilla.kewis.ch  RESOLVED       FIXED
# 245         nobody@mozilla.org  RESOLVED  WORKSFORME
# 246         nobody@mozilla.org  RESOLVED     INVALID
# 247         nobody@mozilla.org  RESOLVED     INVALID
#
#                                                Summary Change Request  \
# 1    (MS) Microsoft Teams meeting description is ma...            ---
# 3          Many errors when setting up zimbra calendar            ---
# 4        Thunderbird with Lightning leaks on Shutdown.            ---
# 5    Events created after 17:00 appear in the next day            ---
# 6    need a strategy for dealing with TZ changes on...            ---
# ..                                                 ...            ...
# 241  iTIP/iMIP invitation bar doesn't disappear aft...            ---
# 242                         Fix calendar eslint issues            ---
# 245  CalDAV: ticket-based access control: DAV_NOT_D...            ---
# 246                                          Home page            ---
# 247                                not show leap year.            ---
#
#     Priority   Severity    Type
# 1         P1     Severe  defect
# 3         P1  NonSevere  defect
# 4         P1  NonSevere  defect
# 5         P1     Severe  defect
# 6         P1     Severe  defect
# ..       ...        ...     ...
# 241       P3  NonSevere  defect
# 242       P3  NonSevere  defect
# 245       P4  NonSevere  defect
# 246       P4     Severe  defect
# 247       P4     Severe  defect
#
# [200 rows x 12 columns]

# %%
# Apply the preprocessing function to the 'Summary' column
bugs_df['Processed_Summary'] = bugs_df['Summary'].apply(lambda x: helper.nlpsteps(x))

# %%
bugs_df['Lowered_Summary'] = bugs_df['Processed_Summary'].apply(lambda x: x.lower())

# %%
print(bugs_df['Lowered_Summary'])
# Out:
# 1      m microsoft team meeting description mangled s...
# 3                     many error setting zimbra calendar
# 4                    thunderbird lightning leak shutdown
# 5                          event created appear next day
# 6          need strategy dealing tz change existing data
#                              ...
# 241    itip imip invitation bar disappear changing e ...
# 242                            fix calendar eslint issue
# 245    caldav ticket based access control dav not_dav...
# 246                                            home page
# 247                                   not_show leap year
# Name: Lowered_Summary, Length: 200, dtype: object

# %%
# Assuming you've already imported necessary libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC

# Initialize CountVectorizer
cv = CountVectorizer()
cv.fit(bugs_df['Lowered_Summary'])

# Transform the processed summaries
X_train = cv.transform(bugs_df['Lowered_Summary'])


# Assuming 'target' is correctly defined
target = bugs_df.iloc[:, -2].values
print("------target", target)


# Initialize LinearSVC
svm = LinearSVC()

# Fit the model
svm.fit(X_train, target)

# Get the coefficients from the trained SVM model
coef = svm.coef_.ravel()

# Get the feature names from CountVectorizer
feature_names = cv.get_feature_names()

# Create a dictionary mapping feature names to coefficients
word_coefficients = {feature_names[i]: coef[i] for i in range(len(feature_names))}

print(word_coefficients)

# # Print the word list and their coefficients
# for word, coefficient in word_coefficients.items():
# #     print(f"{word}: {coefficient:.4f}")

#     if coefficient < 0:
#         severe_lexicons[word] = {"ratio": coefficient}
#     else:
#         non_severe_lexicons[word] = {"ratio": coefficient}

# result = {
#     "Severe Lexicons": severe_lexicons,
#     "NonSevere Lexicon": non_severe_lexicons
# }

# print(result)


# severe_lexicons = {}
# non_severe_lexicons = {}

# for word, coefficient in word_coefficients.items():
#     if coefficient < 0:
#         severe_lexicons[word] = {"ratio": coefficient}
#     else:
#         non_severe_lexicons[word] = {"ratio": coefficient}

# result = {
#     "Severe Lexicons": severe_lexicons,
#     "NonSevere Lexicon": non_severe_lexicons
# }

# print(result)


print(word_coefficients)
# Out:
# target ['m microsoft team meeting description mangled stored google calendar'
#  'many error setting zimbra calendar'
#  'thunderbird lightning leak shutdown' 'event created appear next day'
#  'need strategy dealing tz change existing data'
#  'malformed url cause lightning delete complete calendar file caldav'
#  'changing application timezone not_update time active view'
#  'calendar start fails appmenu button missing toolbar'
#  'new event not_appear today pane cached caldav calendar'
#  'calendar event not_print preview well printout blank'
#  'recurring event missing agenda first load'
#  'google calendar provider ignores default new event task reminder setting'
#  'calendar multiday view not_display day event'
#  'recent change broke blocking master password startup fix'
#  'accepting event secondly frequency recurrence freeze thunderbird gui interaction'
#  'sending separate invitation attendee onlys send email first invited person'
#  'imip bar button type not_adjusted automatically'
#  'autocomplete widget entering email addresse invited attendee participant first one invitation dialog show null value get ignored port bug'
#  'imip bar not_longer displayed string update'
#  'printing not_working javascript error printutils getwebbrowserprint not_a function'
#  'short date display dayview weekview not_localizable'
#  'need todo display lightning'
#  'microsoft team invitation link not_supported'
#  'last modified element ical generated event task'
#  'meta mozmill fix calendar mozmill test'
#  'mozmill fix eventdialog test lightning'
#  'mozmill fix timezonetests lightning'
#  'mozmill fix timezonetests lightning'
#  'self stopediting not_a function creating event via drag drop'
#  'exception recurring event not_handled export icalendar'
#  'storage calendar use index'
#  'recurring event still missing agenda first load'
#  'unable make view smaller resize'
#  'unneccessary refreshing event local calendar startup'
#  'need update snippet lightning nightly build'
#  'accepting invitation google calendar caldav fails error cannot create update event not_the organizer'
#  'database error lightning b database not_been opened'
#  'unable remove event remote zimbra server'
#  'new lightning b new thunderbird critical function not_working win xp sp'
#  'not_take sony ericssion mobies' 'not_show dark spot present date'
#  'event moved lightning one calendar first calendar list'
#  'calendar detail show mouseover entry many line written comment field'
#  'clander view' 'xdfxfcfcnfgjbkj' 'march april' 'march june'
#  'january febuary' 'mozilla calendar project' 'november' 'march june'
#  'february march' 'january second month year' 'alarm'
#  'tomorrow holiday not' 'whether august nd thursday'
#  'countrywide public holiday displayed' 'not_showing festival date'
#  'calender show festival date red colour' 'feb month not_contain day'
#  'lightning b event dialog error calendar content calendar event dialog xul'
#  'lightning completely unusable exception parsing calendar'
#  'festival date not_shown red color'
#  'lightning new task set saved not_register calender event enter everything event'
#  'google calendar empty thunderbird release lightning'
#  'transition winter time russia' 'google calendar not_working'
#  'repeating task cannot marked complete not_updated new task previous repeating task completed'
#  'repeating event changed io app not_updated lightning'
#  'print preview show event color' 'calendar not_displaying home page'
#  'unable accept invitation another caldav user' 'leap year issue'
#  'click help google store error message displayed'
#  'not_modify immutable data container calling method caliitembase setproperty nsresult x n error object immutable ccalstoragecalendar j'
#  'printing calendar fails error'
#  'allow building localized lightning langpacks'
#  'trunk tab break calendar mode view'
#  'thunderbird remove lightning calendar task toolbars'
#  'thunderbird integrate calendar task mode menu item new menu'
#  'today pane integration new thunderbird tab model currently not_available mail tab'
#  'caldav deletes zimbra server often always fail'
#  'thunderbird not_process meeting invite outlook google calendar'
#  'test webcal j fails due redefinition cc'
#  'make lightning test work packaged test'
#  'consolidate calendar helper function switch calutils jsm meta'
#  'lightning window l n repacks fail beta'
#  'fix alarm testcase thrown exception changed'
#  'fix parent component accessor cloning timezone ref make test pas'
#  'store large integer value string cannot set xxx pref number yyy number pref value must signed bit integer range'
#  'check calendar setproperty xyz null reset pref fails'
#  'morocco holiday without religious holiday'
#  'mozmill test not_work tb build change'
#  'code review bug provider google calendar cannot sync task'
#  'invalid time zone definition start time'
#  'accepting inviations work expected forbidden'
#  'google agenda desappear not_connected'
#  'event daylight saving time change one hour'
#  'lightning extremely slow unresponsive google birthday calendar'
#  'provider not_sync single occurrence deleted occurrence'
#  'not_set absolute alarm event start'
#  'alarmlastack not_taken parent item alarm service'
#  'test unexpected fail xpcshell icaljs ini calendar test unit test gdata provider j xpcshell return code'
#  'gdata provider creates duplicate event recurring event edited saved synchronized'
#  'test using calendar startup fail xpcshell failure calendar abort file mozilla dom worker serviceworkerregistrar cpp line friday bustage'
#  'fix linting c c try c c'
#  'dynamic registration unregistration calendar provider'
#  'event encoding messed caldav'
#  'update icloud caldav possible since march'
#  'importing ic file todo item fails j error'
#  'lightning pane repaint calendar added deleted'
#  'use intl datetimeformat instead nsiscriptabledateformat'
#  'update internal timezone database version b version'
#  'lightning identify calendar radicale server interface lock trying'
#  'thunderbird pause second time even minute stuck icaltimezone compare change fn icaltime compare ical j'
#  'caldav event corruption thunderbird upgrade'
#  'set builder lightning b pre thunderbird'
#  'need support event not_all day span multiple day'
#  'multiday view need pref control start end day start end week'
#  'need specify context menu view'
#  'calendar implement new handling bad server certificate ssl tl connection'
#  'accept event invitation reply wrongly sent confirmed email associated accepting calendar tb default account instead recipient attendee email address privacy leak'
#  'displayed reminder improperly snoozed duplicated calendar refreshed'
#  'mozmill make recurrence test work'
#  'mozmill fix calendar recurrencerotated test'
#  'mozmill calendar make mozmill not_working window'
#  'mozmill calendar recurrence test regularly failing linux'
#  'mozmill testweeklywithexceptionrecurrence j failing platform linux others'
#  'update internal timezone database version version b'
#  'detect system timezone javascript internationalization api'
#  'update internal timezone database version c'
#  'marking repeated task complete mark instance task'
#  'event arriving via imip handled zimbra server lightning creates weird user experience'
#  'assertion expected one call gcallcount shutting thunderbird lightning'
#  'assertion get xpt search path shutting thunderbird lightning'
#  'draging e mail lightning way disable attendee event task'
#  'install lightning b tb linux xpi failed' 'disable leap year'
#  'mistake july month' 'september month show wrong'
#  'september month show wrong' 'navigation not_found' 'testing app'
#  'february month not_contain day' 'lightning not_compatible thunderbird'
#  'calender note not_taking date' 'calendar disabled'
#  'invitation ic file generated daylight crash thunderbird enabled lightning'
#  'duplicated day enumeration displayed month view sept shown twice st oct missing'
#  'thunderbird calendar not_show calendar event'
#  'update story timezone database'
#  'make test interface function test recur j robust'
#  'running xpcshell test mac production builder fails lightning'
#  'infinite loop refresh ic server calendar not_available'
#  'clicking mid url calendar entry longer open mail make message convert event useless ux'
#  'use new o x button'
#  'first run wizard dialog not_close clicking advanced config'
#  'remove legacy generator calendar provider gdata'
#  'item overrun boundary lightning option tab'
#  'miniday show dummy value year month starttime'
#  'need better mechanism switching view mode tbird'
#  'view need colourize event calendar color pref'
#  'edit calendar dialog email warning clipped'
#  'opening one event multiple event window opened instead switching already opened window'
#  'calialarm need nicer support multiple trigger type etc'
#  'mass replace component interface component utils us ci cu calendar'
#  'fix underlying issue worked around test caldav client xpcshell test'
#  'need properly de serialize calialarms ic'
#  'add jscoverage report lightning unit test' 'lightning rc still work tb'
#  'date font small' 'calendar date not_showing properly' 'dump' 'alarm'
#  'november month name show wrong' 'november month show wrong'
#  'problem leap year' 'september month shown wrong'
#  'november show wrong display' 'leap year problem' 'septeber month wrong'
#  'leap year problem' 'calendar not_displaying home page'
#  'could not_extract integer file resource calendar module ical j line'
#  'remove two instance recurring event synchronization google calendar break'
#  'test unexpected fail xpcshell icaljs ini calendar test unit test alarmservice j test unexpected fail xpcshell icaljs ini calendar test unit test datetime j'
#  'allowable calendar duplicate need distribution prepended path aurora'
#  'firefox download end time lightning alarm time offset one turkey utc timezone'
#  'ic preview hide mail body'
#  'calendar date time formatting not_follow regional setting'
#  'computer sleep overnight current day highlighting not_update pushing go today button not_correct'
#  'styling not_right event dialog time picker'
#  'today pane shown tab like preference tab'
#  'drag drop calendar event month multiweek view work'
#  'today pane tomorrow upcoming toggle get stuck'
#  'itip imip invitation bar disappear changing e mail folder'
#  'fix calendar eslint issue'
#  'caldav ticket based access control dav not_dav read failed error'
#  'home page' 'not_show leap year']
# {'abort': 0.0, 'absolute': -0.0011100454450233294, 'accept': 0.08342022693536513, 'accepting': 0.07353688165370467, 'access': 0.0, 'accessor': 0.0, 'account': 0.11571576738161932, 'active': 0.0, 'add': 0.0, 'added': 0.0, 'address': 0.11571576738161932, 'addresse': -0.009201039352600285, 'advanced': 0.0, 'agenda': -0.009427727480539876, 'alarm': -0.04885932899050827, 'alarmlastack': -0.0016086441343019816, 'alarmservice': 0.0, 'allow': -4.394308005872868e-05, 'allowable': -0.0021538696419979445, 'already': -0.008807984853777817, 'always': -0.0011711558259738012, 'another': -0.03229554044625419, 'api': -0.006975451952231984, 'app': -0.024156197283123203, 'appear': -0.011390212000403448, 'application': 0.0, 'appmenu': -0.0011719578348334504, 'april': -0.012849335426227277, 'around': 0.0, 'arriving': 0.0, 'assertion': 0.0, 'associated': 0.11571576738161932, 'attendee': 0.0658712009393293, 'august': -0.013420929034406934, 'aurora': -0.0021538696419979445, 'autocomplete': -0.009201039352600285, 'automatically': -0.0053910888312191235, 'bad': -0.001540092540280881, 'bar': -0.013528182708890373, 'based': 0.0, 'beta': 0.0, 'better': -0.0009784802861338728, 'birthday': 0.0, 'bit': -0.0011126498249517495, 'blank': -0.003670507634360981, 'blocking': -0.0011760050037979053, 'body': -0.004491460401968062, 'boundary': 0.0, 'break': 0.0, 'broke': -0.0011760050037979053, 'bug': -0.009201039352600285, 'build': -0.021214942641330625, 'builder': 0.0, 'building': -4.394308005872868e-05, 'bustage': 0.0, 'button': -0.010847071811607233, 'cached': 0.0, 'caldav': -0.04148112864533833, 'calendar': -0.024947255522701165, 'calender': -0.006949263386150301, 'calialarm': -0.003622444424912702, 'calialarms': -0.005749305751599896, 'caliitembase': -0.0029352228411033444, 'call': 0.0, 'calling': -0.0029352228411033444, 'calutils': -0.003647245430206805, 'cannot': -0.0025099025275005173, 'cause': 0.0, 'cc': -0.004558507410577853, 'ccalstoragecalendar': -0.0029352228411033444, 'certificate': -0.001540092540280881, 'change': -0.024858458508674658, 'changed': 0.0, 'changing': -0.006667814357531353, 'check': -0.0010734592820452118, 'ci': -0.003082383268907831, 'clander': -0.022144375921932025, 'click': -0.0007876382059303376, 'clicking': -0.0012037139351921034, 'client': 0.0, 'clipped': -0.03864895415376279, 'cloning': 0.0, 'code': 0.0, 'color': -0.009910729575894051, 'colour': 0.0, 'colourize': 0.0, 'comment': -0.0013472879370163985, 'compare': 0.0, 'complete': -0.0017160326508470322, 'completed': 0.0, 'completely': 0.0, 'component': -0.006164766537815662, 'computer': -0.0021792884180318935, 'config': 0.0, 'confirmed': 0.11571576738161932, 'connection': -0.001540092540280881, 'consolidate': -0.003647245430206805, 'container': -0.0029352228411033444, 'content': 0.0, 'context': -0.004055180807483293, 'control': 0.0, 'convert': -0.0012037139351921034, 'corruption': 0.0, 'could': -0.0027976879329822584, 'countrywide': -0.008651019435238846, 'cpp': 0.0, 'crash': 0.0, 'create': -0.0013972527025487684, 'created': -0.011390212000403448, 'creates': -0.002424237780395274, 'creating': -0.005876499944045812, 'critical': 0.0, 'cu': -0.003082383268907831, 'current': -0.0021792884180318935, 'currently': 0.0, 'dark': -0.004335849695270198, 'data': -0.00540273370464948, 'database': -0.012838840556186597, 'date': -0.03607111949724468, 'datetime': 0.0, 'datetimeformat': -0.02985601414101804, 'dav': 0.0, 'day': -0.018156507071865093, 'daylight': 0.0, 'dayview': -0.00442243872585693, 'de': -0.005749305751599896, 'dealing': -0.0024675108635461352, 'default': 0.103820903767435, 'definition': -0.004108355283206202, 'delete': 0.0, 'deleted': -0.004871571054353052, 'deletes': -0.0011711558259738012, 'desappear': -0.009427727480539876, 'description': 0.0, 'detail': -0.0013472879370163985, 'detect': -0.006975451952231984, 'dialog': -0.0478499935063631, 'disable': -0.009284767283159582, 'disabled': -0.02363055625666815, 'disappear': -0.006667814357531353, 'display': -0.004422438725856931, 'd ...
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# def plot_coefficients(classifier, feature_names, top_features=20):
#     coef = classifier.coef_.ravel()
#     top_positive_coefficients = np.argsort(coef)[-top_features:]
#     top_negative_coefficients = np.argsort(coef)[:top_features]
#     top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])

#     # create plot
#     plt.figure(figsize=(15, 5))
#     colors = ['red' if c < 0 else 'blue' for c in coef[top_coefficients]]
#     plt.bar(np.arange(2 * top_features), coef[top_coefficients], color=colors)
#     feature_names = np.array(feature_names)
#     plt.xticks(np.arange(1, 1 + 2 * top_features), feature_names[top_coefficients], rotation=60, ha='right')
#     plt.show()

# cv = CountVectorizer()
# cv.fit(bugs_df['Summary'])
# print("length", len(cv.vocabulary_))
# print("Feature Names", cv.get_feature_names())
# X_train = cv.transform(bugs_df['Summary'])
# target = bugs_df.iloc[:, -2].values
# print("target",target)

# svm = LinearSVC()
# svm.fit(X_train, target)
# plot_coefficients(svm, cv.get_feature_names())

# #Get the coefficients from the trained SVM model
# coef = svm.coef_.ravel()

# # Get the feature names from the CountVectorizer
# feature_names = cv.get_feature_names()

# # Create a dictionary mapping feature names to coefficients
# word_coefficients = {feature_names[i]: coef[i] for i in range(len(feature_names))}

# # Print the word list and their coefficients
# for word, coefficient in word_coefficients.items():
#     print(f"{word}: {coefficient:.4f}")

# %%
# # [ 1  2  8  9 11 12 16 17 18 19]
# def plot_coefficients(classifier, feature_names, top_features=30):
#     coef = classifier.coef_.ravel()
#     top_positive_coefficients = np.argsort(coef)[-top_features:]
#     top_negative_coefficients = np.argsort(coef)[:top_features]
#     top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])

#     # create plot
#     plt.figure(figsize=(15, 5))
#     colors = ['red' if c < 0 else 'blue' for c in coef[top_coefficients]]
#     plt.bar(np.arange(2 * top_features), coef[top_coefficients], color=colors)
#     feature_names = np.array(feature_names)
#     plt.xticks(np.arange(1, 1 + 2 * top_features), feature_names[top_coefficients], rotation=60, ha='right')
#     plt.show()

# cv = CountVectorizer()
# cv.fit(bugs_df['Summary'])
# X_train = cv.transform(bugs_df['Summary'])
# # print(bugs_df['Summary'])
# target = bugs_df.iloc[:, -2].values
# # print(target)

# # Separate the data into severe and non-severe classes
# severe_indices = np.where(target == 'Severe')[0]
# non_severe_indices = np.where(target == 'NonSevere')[0]

# print("severe_indices", severe_indices)
# print("non_severe_indices", non_severe_indices)

# # Train separate SVM models for severe and non-severe classes
# svm_severe = LinearSVC()
# svm_severe.fit(X_train[severe_indices], target[severe_indices])
# print(svm_severe)

# svm_non_severe = LinearSVC()
# svm_non_severe.fit(X_train[non_severe_indices], target[non_severe_indices])

# # Get the coefficients from the trained SVM models
# coef_severe = svm_severe.coef_.ravel()
# coef_non_severe = svm_non_severe.coef_.ravel()

# # Create dictionaries mapping feature names to coefficients for severe and non-severe classes
# word_coefficients_severe = {feature_names[i]: coef_severe[i] for i in range(len(feature_names))}
# word_coefficients_non_severe = {feature_names[i]: coef_non_severe[i] for i in range(len(feature_names))}

# # Print the word list and their coefficients for both classes
# for word in feature_names:
#     print(f"{word}: Severe={word_coefficients_severe.get(word, 0):.4f}, Non-Severe={word_coefficients_non_severe.get(word, 0):.4f}")
