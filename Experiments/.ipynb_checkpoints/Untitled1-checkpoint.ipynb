# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import json
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/fatimaa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
bugs_eclipse = pd.read_csv("bugs_eclipse.csv")

# %%
bugs_eclipse.head(20)
# Out:
#     Bug ID             Product      Component  \
# 0   224846   WTP Java EE Tools       jst.j2ee
# 1   315662     WTP ServerTools     wst.server
# 2   231453          WTP Releng         releng
# 3   250101                JSDT        General
# 4   316062   Java Server Faces  Documentation
# 5   513578     WTP ServerTools     wst.server
# 6    92916    WTP Common Tools     wst.common
# 7   180054     WTP Webservices         jst.ws
# 8   322295   WTP Java EE Tools       jst.j2ee
# 9   461160                JSDT        General
# 10  102958   WTP Java EE Tools       jst.j2ee
# 11  169749       WTP EJB Tools        jst.ejb
# 12  102999       WTP EJB Tools        jst.ejb
# 13  100441   WTP Java EE Tools       jst.j2ee
# 14  186938   WTP Java EE Tools        jst.jem
# 15  188416    WTP Common Tools     wst.common
# 16  258742     WTP ServerTools     wst.server
# 17  159966     WTP ServerTools     wst.server
# 18  104121  WTP Source Editing        wst.xml
# 19  117007    WTP Common Tools     wst.common
#
#                              Assignee    Status Resolution  \
# 0                   kaloyan@raev.name    CLOSED      FIXED
# 1                   arvera@ca.ibm.com  RESOLVED      FIXED
# 2              david_williams@acm.org  VERIFIED      FIXED
# 3                  childsb@us.ibm.com  RESOLVED      FIXED
# 4   raghunathan.srinivasan@oracle.com    CLOSED      FIXED
# 5                    eyuen7@gmail.com  RESOLVED      FIXED
# 6                  mdelder@us.ibm.com    CLOSED      FIXED
# 7              david_williams@acm.org    CLOSED      FIXED
# 8                      ccc@us.ibm.com  RESOLVED      FIXED
# 9                vrubezhny@redhat.com  RESOLVED      FIXED
# 10                  dfholt@us.ibm.com    CLOSED      FIXED
# 11             naci.dai@eteration.com    CLOSED      FIXED
# 12                vbhadrir@us.ibm.com    CLOSED  DUPLICATE
# 13                  jsholl@us.ibm.com    CLOSED      FIXED
# 14                cbridgha@us.ibm.com    CLOSED      FIXED
# 15                 csalter@ca.ibm.com    CLOSED      FIXED
# 16                  deboer@redhat.com    CLOSED      FIXED
# 17                  deboer@redhat.com    CLOSED      FIXED
# 18             david_williams@acm.org    CLOSED  DUPLICATE
# 19        konstantin@komissarchik.net    CLOSED      FIXED
#
#                                               Summary           Changed  \
# 0   Cannot create Java EE artifacts: servlet, bean...   12/05/2008 9:38
# 1                        Discovery plugin regressions  11/10/2017 16:33
# 2   P2 doesn't install all features, compared to U...  29/06/2018 15:25
# 3                Versioning issues on latet 3.1 build  03/03/2010 11:16
# 4   [doc] "New and Noteworthy" document in JSF Use...  19/12/2017 13:26
# 5   [Oxygen] Modify url in discovery plugin for jb...  11/10/2017 16:45
# 6                    Failing JUnit tests [wst.common]  26/07/2005 14:11
# 7   Error when copying Axis jar files to web proje...  03/04/2007 11:46
# 8        CommonEditorUtility does not compile with e4   16/08/2010 9:24
# 9   Backport the fix for 'Bug 433515 - Eclipse fre...  02/04/2015 17:31
# 10  Module factory is failing to show the connecto...  26/07/2005 14:11
# 11  dtp dependancies should be optional for JST In...  02/07/2007 13:11
# 12  Unable to get cmp field types when java source...  26/07/2005 14:07
# 13  class path errors after ejb  jar import  with ...  13/07/2005 15:43
# 14  org.eclipse.jem.beaninfo - missing classpath e...  06/06/2007 15:40
# 15       URIResolverExtension passed incorrect inputs  30/10/2007 10:19
# 16  need to react to Platorm change in jetty packa...  11/10/2017 16:26
# 17            Module creation no longer handles null?  11/10/2017 16:05
# 18  XML file generated from XSD has null encoding,...  25/09/2006 16:25
# 19  ProjectFacet constraint validation can go into...  26/09/2006 10:10
#
#    Priority Severity
# 0        P1  blocker
# 1        P1  blocker
# 2        P1  blocker
# 3        P1  blocker
# 4        P1  blocker
# 5        P1  blocker
# 6        P1  blocker
# 7        P1  blocker
# 8        P1  blocker
# 9        P1  blocker
# 10       P1  blocker
# 11       P1  blocker
# 12       P1  blocker
# 13       P1  blocker
# 14       P1  blocker
# 15       P1  blocker
# 16       P1  blocker
# 17       P1  blocker
# 18       P1  blocker
# 19       P1  blocker

# %%
bugs_eclipse_length = len(bugs_eclipse)

# %%
def nlpsteps(x):
    """
    Tokenizes and preprocesses a summary of a bug.

    Args:
        x (str): The summary text to be processed.

    Returns:
        str: The processed text after removing non-alphabetic characters, converting to lowercase,
             lemmatizing words, and removing stopwords.
    """
    
    # Remove non-alphabetic characters
    review = re.sub('[^a-zA-Z]', ' ', str(x))
    review = review.lower()
    review = review.split()

    # Initialize WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()

    # Remove stopwords and lemmatize words
    all_stopwords = set(stopwords.words('english'))
    all_stopwords.remove('not')
    review = [lemmatizer.lemmatize(word) for word in review if word not in all_stopwords]

    # Join the processed words back into a sentence
    review = ' '.join(review)
    return review

# %%
def convert(corpus_trainingdata):
    """
    Data after preprocessing splitting into separate words

    Args:
        corpus_trainingdata: Preprocessed data of the training dataset
     
    Returns: Splitted words
    """
#     print("DEMO--------------------------Corpus---------------------------")
#     print(corpus_trainingdata)
    return ([i for item in corpus_trainingdata for i in item.split()])

# %%
def get_distribution(val,bugs_eclipse):
    """
    Data after preprocessing splitting into separate words

    Args:
        val: Preprocessed data of the training dataset
        training_data_df: training dataset dataframe
      
    Returns: Splitted words
    """
    bugs_eclipse['Summary'] = bugs_eclipse['Summary'].apply(lambda x: nlpsteps(x))
    records = bugs_eclipse[
        bugs_eclipse["Summary"].str.contains(val)
    ]
    
    if len(records) > 0:
        res = bugs_eclipse[
            training_data_df["Summary"].str.contains(val)
        ]["Severity"].value_counts(dropna=False)
        return dict(res)
    return None

# %%
def lexicon_preprocess(trainingdataset_length,training_data_df):
    """
    Create wordlists for severe and non severe from the preprocessed training dataset 

    Args:
        trainingdataset_length: size of training dataset
        training_data_df: training dataset dataframe
      
    Returns: a wordlist that has words from training dataset with its counts for severe and nonsevere
    """

    corpus_trainingdata = []
    all_data_df_ = []
       
    for i in range(0,trainingdataset_length):
        review = nlpsteps(str(training_data_df['Summary'][i]))
        corpus_trainingdata.append(review)
   

    #Split words from the corpus
    splittedWords = convert(corpus_trainingdata)
#     print("splittedWords---------------", splittedWords)
    
    splitted_words=getwordcounts(splittedWords)

    #Converted collection.counter into dictionary
    splitted_words_dict = dict(splitted_words)

    keys = splitted_words_dict.keys()
    
    all_data = {}
    for key in keys:
        res = get_distribution(key,training_data_df)
        if res:
            all_data[key] = res
            all_data
            all_data_df = pd.DataFrame(all_data)
       
            print("--------------wordlists for severe and non-severe------------------------")
         
            pd.set_option('display.max_columns', None)
            print(all_data_df)
        

    return payload_train

# %%
payload_train = lexicon_preprocess(bugs_eclipse_length,bugs_eclipse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 payload_train = lexicon_preprocess(bugs_eclipse_length,bugs_eclipse)
#
# Cell In[40], line 16, in lexicon_preprocess(trainingdataset_length, training_data_df)
#      13 all_data_df_ = []
#      15 for i in range(0,trainingdataset_length):
# ---> 16     review = nlpsteps(str(training_data_df['Summary'][i]))
#      17     corpus_trainingdata.append(review)
#      20 #Split words from the corpus
#
# Cell In[32], line 19, in nlpsteps(x)
#      16 review = review.split()
#      18 # Initialize WordNetLemmatizer
# ---> 19 lemmatizer = WordNetLemmatizer()
#      21 # Remove stopwords and lemmatize words
#      22 all_stopwords = set(stopwords.words('english'))
#
# NameError: name 'WordNetLemmatizer' is not defined

# %%
payload_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 payload_train
#
# NameError: name 'payload_train' is not defined
