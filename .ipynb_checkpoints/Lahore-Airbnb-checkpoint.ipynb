# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

from multiprocessing import Pool

import os

# %%
url = "https://www.airbnb.com/s/DHA--Lahore--Punjab--Pakistan/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=march&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&checkin=2022-04-10&checkout=2022-04-11&source=structured_search_input_header&search_type=filter_change&query=DHA%2C%20Lahore%2C%20Punjab%2C%20Pakistan&place_id=ChIJQdjg4XYGGTkRoPj9lHJrTdE&adults=1"

# r = requests.get(url)
# soup = BeautifulSoup(r.content, 'html.parser')
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

print(soup.prettify())	# to print html in tree structure
# Out:
# <!DOCTYPE html>
# <html data-is-hyperloop="true" dir="ltr" lang="en">
#  <meta charset="utf-8"/>
#  <meta content="en" name="locale"/>
#  <meta content="notranslate" name="google"/>
#  <meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/>
#  <meta content="" id="csrf-token-meta-tag" name="csrf-token"/>
#  <meta content="" id="english-canonical-url"/>
#  <meta content="on" name="twitter:widgets:csp"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="Airbnb" name="application-name"/>
#  <meta content="Airbnb" name="apple-mobile-web-app-title"/>
#  <meta content="#ffffff" name="theme-color"/>
#  <meta content="#ffffff" name="msapplication-navbutton-color"/>
#  <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="/?utm_source=homescreen" name="msapplication-starturl"/>
#  <script>
#   (function() {
# ...

# %%
listings = get_listings(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5d/403ycky539l56zh62k4t0x9m0000gn/T/ipykernel_5119/1371345912.py in <module>
# ----> 1 listings = get_listings(url)
#
# NameError: name 'get_listings' is not defined

# %%
len(listings)

# %%
print(listings[0].prettify())
# Out:
# <div class="_gig1e7">
#  <div class="cd239om dir dir-ltr">
#   <div class="ch1c6qs lusz0gm dir dir-ltr" style="--transition-element_transition-delay:0ms">
#    <div class="_11ry7lz" data-testid="shimmer-legacy-listing-section-item">
#     <div style="margin-top:12px;margin-bottom:24px">
#      <div class="_7qp4lh">
#      </div>
#     </div>
#     <div class="c1k4n2ms dir dir-ltr">
#      <div class="mertcch dir dir-ltr">
#       <span aria-busy="true" style="display:block;height:100%;width:100%;background-color:white;border-radius:var(--i-g-gvoq)">
#        <span class="_8kplbn" style="animation-play-state:running;height:100%;width:100%;border-radius:var(--i-g-gvoq)">
#        </span>
#       </span>
#      </div>
#      <div class="iabnva0 dir dir-ltr">
#       <div style="margin-bottom:4px">
#        <span aria-busy="true" style="display:block;height:18px;width:40%;background-color:white;border-radius:10px">
# ...

# %% [markdown]
# # Tree Traverse

# %%
title = soup.title
print(title)
# Out:
# <title>Airbnb: Vacation Rentals, Cabins, Beach Houses, Unique Homes &amp; Experiences</title>

# %%
soup.find_all('div')[6].get_text()
# Out:
# ' DHA, Lahore, Punjab, PakistanShow map'

# %%
print(type(title))
print(type(soup))
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.BeautifulSoup'>

# %%
listings = soup.find_all('div', '_gig1e7')

# %%
listings[0]
# Out:
# <div class="_gig1e7"><div class="cd239om dir dir-ltr"><div class="ch1c6qs lusz0gm dir dir-ltr" style="--transition-element_transition-delay:0ms"><div class="_11ry7lz" data-testid="shimmer-legacy-listing-section-item"><div style="margin-top:12px;margin-bottom:24px"><div class="_7qp4lh"></div></div><div class="c1k4n2ms dir dir-ltr"><div class="mertcch dir dir-ltr"><span aria-busy="true" style="display:block;height:100%;width:100%;background-color:white;border-radius:var(--i-g-gvoq)"><span class="_8kplbn" style="animation-play-state:running;height:100%;width:100%;border-radius:var(--i-g-gvoq)"></span></span></div><div class="iabnva0 dir dir-ltr"><div style="margin-bottom:4px"><span aria-busy="true" style="display:block;height:18px;width:40%;background-color:white;border-radius:10px"><span class="_8kplbn" style="animation-play-state:running;height:100%;width:100%;border-radius:10px"></span></span></div><span aria-busy="true" style="display:block;height:24px;width:90%;background-color:whi
# ...

# %%
listings = soup.find_all('div', 'mj1p6c8')

# %%
listings[0].get_text()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/5d/403ycky539l56zh62k4t0x9m0000gn/T/ipykernel_5119/3452824517.py in <module>
# ----> 1 listings[0].get_text()
#
# IndexError: list index out of range
